# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen, HTTPError
import csv

# %% [markdown]
# ## Save working links of competition score reports to CSV

# %%
next_year_dict = {}
for year in range(4, 19):
    year_str = '0'+str(year) if year<10 else str(year)
    next_year = year + 1
    next_year_str = '0'+str(next_year) if next_year<10 else str(next_year)
    next_year_dict[year_str] = next_year_str

# %%
def parse_link(template, verbose=False):
    # Return HTML content of given link/template and print progress status
    try:
        html = urlopen(template)
        if verbose:
            print('sucess:', template)
        return html
    except HTTPError as e:
        if verbose:
            print('failure:', template)
        return None

# %%
gp_templates = [    
    'http://www.isuresults.com/results/gp{0}{1}/CAT00{3}RS.HTM',
    'http://www.isuresults.com/results/gp{0}20{1}/CAT00{3}RS.HTM',
    'http://www.isuresults.com/results/gp{0}{1}{2}/CAT00{3}RS.HTM',
    'http://www.isuresults.com/results/season{1}{2}/gp{0}{1}{2}/CAT00{3}RS.HTM',
    'http://www.isuresults.com/results/season{1}{2}/gp{0}{1}{2}/data0{3}90.htm',
    'http://www.isuresults.com/results/season{1}{2}/gp{0}20{1}/CAT00{3}RS.HTM',
    'http://www.isuresults.com/results/season{1}{2}/gp{0}20{1}/data0{3}90.htm'      
]
cp_templates = [
    'http://www.isuresults.com/results/{0}20{2}/CAT00{3}RS.HTM',
    'http://www.isuresults.com/results/season{1}{2}/{0}20{2}/CAT00{3}RS.HTM'
]

# %%
gp_events = ['usa', 'can', 'fra', 'rus', 'chn', 'jpn', 'fin', 'f']
cp_events = ['ec', 'fc', 'owg', 'wc']
events = gp_events + cp_events

# Give event abbreviations better names
event_new_names = ['US', 'CA', 'FR', 'RU', 'CN', 'JP', 'FI', 'FN', 'EU', '4C', 'OL', 'WR']
event_name_dict = dict(zip(events, event_new_names))
event_name_dict
# Out:
# {'usa': 'US',
#  'can': 'CA',
#  'fra': 'FR',
#  'rus': 'RU',
#  'chn': 'CN',
#  'jpn': 'JP',
#  'fin': 'FI',
#  'f': 'FN',
#  'ec': 'EU',
#  'fc': '4C',
#  'owg': 'OL',
#  'wc': 'WR'}

# %% [markdown]
# Save all male links to CSV

# %%
with open('links/male.csv', mode='w') as file:    
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(['event', 'year', 'url'])
    for event in events:
        for year_str, next_year_str in next_year_dict.items():
            
            # Events where senior male results are pushed down (higher index in URL)
            if (next_year_str == '12' and event == 'wc') or (year_str in ['08', '09'] and event == 'f'):
                gender = '5'
            elif next_year_str in ['11', '12'] and event in ['ec', 'wc']:
                gender = '4'
            # Most other events: male results usually have index = 1 in URL
            else:
                gender = '1'
            
            # Different URL templates for Grand Prix and Euro/4C/Olympics/World events
            templates = gp_templates if event in gp_events else cp_templates
            
            # Try different URL templates until getting a working URL
            for template in templates:
                # Fill in event name, year, and gender index to URL template before parsing it
                template = template.format(event, year_str, next_year_str, gender)
                html = parse_link(template)
                if html is not None:
                    # Write link to CSV with associated (reformatted) event name and year (20xx int format)
                    writer.writerow([event_name_dict[event], int('20'+next_year_str), template])
                    break

# %% [markdown]
# Save all female links to CSV

# %%
with open('links/female.csv', mode='w') as file:
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(['event', 'year', 'url'])
    for event in events:
        for year_str, next_year_str in next_year_dict.items():
            
            # Events where senior female results are pushed down (higher index in URL)
            if (next_year_str == '12' and event == 'wc') or (year_str in ['08', '09'] and event == 'f'):
                gender = '6'
            elif next_year_str in ['11', '12'] and event in ['ec', 'wc']:
                gender = '5'
            # Most other events: male results usually have index = 2 in URL
            else:
                gender = '2'
            
            # Different URL templates for Grand Prix and Euro/4C/Olympics/World events
            templates = gp_templates if event in gp_events else cp_templates
            
            # Try different URL templates until getting a working URL
            for template in templates:
                # Fill in event name, year, and gender index to URL template before parsing it
                template = template.format(event, year_str, next_year_str, gender)
                html = parse_link(template)
                if html is not None:
                    # Write link to CSV with associated (reformatted) event name and year (20xx int format)
                    writer.writerow([event_name_dict[event], int('20'+next_year_str), template])
                    break

# %% [markdown]
# ## Parse scores from saved links

# %% [markdown]
# Read URL links from saved CSV

# %%
male_links = pd.read_csv('links/male.csv')
male_links = pd.pivot(values=male_links['url'], index=male_links['event'], columns=male_links['year'])

# %%
female_links = pd.read_csv('links/female.csv')
female_links = pd.pivot(values=female_links['url'], index=female_links['event'], columns=female_links['year'])

# %% [markdown]
# Read skater counts for each event (to get how many rows to scrap from each link)

# %%
male_counts = pd.read_csv('counts/male.csv', index_col=0)
female_counts = pd.read_csv('counts/female.csv', index_col=0)

# %%
def parse_score(link, event, year, skater_count, process=True, verbose=False):
    html = urlopen(link)
    try:
        bs = BeautifulSoup(html.read(), 'html.parser')

        table_str = str(bs.findAll('table')[0])
        table = pd.read_html(table_str)[0]
        if process:
            if year == 2005 and event == 'US':
                name_col, score_col, start_row = 1, 3, 1
            elif (year in [2018, 2019] and event == 'JP') or (year == 2018 and event == 'FN'):
                name_col, score_col, start_row = 1, 5, 1
            elif year in range(2005, 2008):
                name_col, score_col, start_row = 1, 3, 3
            elif year in range(2008, 2020):
                name_col, score_col, start_row = 1, 6, 2
            if verbose:
                print(f'name_col: {name_col}, score_col: {score_col}, start_row: {start_row}')
            table = table[[name_col, score_col]].dropna().iloc[start_row:start_row+skater_count, :]
            table.columns = ['name', 'score']
            table['score'] = table['score'].astype(float)
            table['event'] = event            
            table['year'] = year
        return table
    except Exception as e:
        print('failure:', link)
        print(e)
        return None

# %%
male_scores = []
for year in range(2005, 2020):
    for event in event_name_dict.values():
        link = male_links.loc[event, year]
        if not pd.isnull(link):
            print(f'{year}, {event}: {link}')
            score = parse_score(link, event, year, skater_count=male_counts.loc[year, event], process=True)
            male_scores.append(score)
# Out:
# 2005, US: http://www.isuresults.com/results/gpusa04/CAT001RS.HTM
# 2005, CA: http://www.isuresults.com/results/gpcan04/CAT001RS.HTM
# 2005, FR: http://www.isuresults.com/results/gpfra04/CAT001RS.HTM
# 2005, RU: http://www.isuresults.com/results/gprus04/CAT001RS.HTM
# 2005, CN: http://www.isuresults.com/results/gpchn04/CAT001RS.HTM
# 2005, JP: http://www.isuresults.com/results/gpjpn04/CAT001RS.HTM
# 2005, FN: http://www.isuresults.com/results/gpf0405/CAT001RS.HTM
# 2005, EU: http://www.isuresults.com/results/ec2005/CAT001RS.HTM
# 2005, 4C: http://www.isuresults.com/results/fc2005/CAT001RS.HTM
# 2017, EU: http://www.isuresults.com/results/season1617/ec2017/CAT001RS.HTM
# 2017, 4C: http://www.isuresults.com/results/season1617/fc2017/CAT001RS.HTM
# 2017, WR: http://www.isuresults.com/results/season1617/wc2017/CAT001RS.HTM
# 2018, US: http://www.isuresults.com/results/season1718/gpusa2017/CAT001RS.HTM
# 2018, CA: http://www.isuresults.com/results/season1718/gpcan2017/CAT001RS.HTM
# 2018, FR: http://www.isuresults.com/results/season1718/gpfra2017/CAT001RS.HTM
# 2018, RU: http://www.isuresults.com/results/season1718/gprus2017/CAT001RS.HTM
# 2018, CN: http://www.isuresults.com/results/season1718/gpchn2017/CAT001RS.HTM
# 2018, JP: http://www.isuresults.com/results/season1718/gpjpn2017/data0190.htm
# 2018, FN: http://www.isuresults.com/results/season1718/gpf1718/data0190.htm
# 2018, EU: http://www.isuresults.com/results/season1718/ec2018/CAT001RS.HTM
# 2018, 4C: http://www.isuresults.com/results/season1718/fc2018/CAT001RS.HTM
# 2018, OL: http://www.isuresults.com/results/season1718/owg2018/CAT001RS.HTM
# 2018, WR: http://www.isuresults.com/results/season1718/wc2018/CAT001RS.HTM
# 2019, US: http://www.isuresults.com/results/season1819/gpusa2018/CAT001RS.HTM
# 2019, CA: http://www.isuresults.com/results/season1819/gpcan2018/CAT001RS.HTM
# 2019, FR: http://www.isuresults.com/results/season1819/gpfra2018/CAT001RS.HTM
# 2019, RU: http://www.isuresults.com/results/season1819/gprus2018/CAT001RS.HTM
# 2019, JP: http://www.isuresults.com/results/season1819/gpjpn2018/data0190.htm
# 2019, FI: http://www.isuresults.com/results/season1819/gpfin2018/CAT001RS.HTM
# 2019, FN: http://www.isuresults.com/results/season1819/gpf1819/CAT001RS.HTM
# 2019, EU: http://www.isuresults.com/results/season1819/ec2019/CAT001RS.HTM
# 2019, 4C: http://www.isuresults.com/results/season1819/fc2019/CAT001RS.HTM

# %%
male_scores_df = pd.concat(male_scores,axis=0).reset_index(drop=True)
male_count_check = male_scores_df.groupby(['year', 'event']).size()
male_count_check = male_count_check.unstack().fillna(0).astype(int)
male_count_check = male_count_check.loc[male_counts.index, male_counts.columns]
np.all(male_count_check == male_counts)
# Out:
# True

# %%
female_scores = []
for year in range(2005, 2020):
    for event in event_name_dict.values():
        link = female_links.loc[event, year]
        if not pd.isnull(link):
            print(f'{year}, {event}: {link}')
            score = parse_score(link, event, year, skater_count=female_counts.loc[year, event], process=True)
            female_scores.append(score)
# Out:
# 2005, US: http://www.isuresults.com/results/gpusa04/CAT002RS.HTM
# 2005, CA: http://www.isuresults.com/results/gpcan04/CAT002RS.HTM
# 2005, FR: http://www.isuresults.com/results/gpfra04/CAT002RS.HTM
# 2005, RU: http://www.isuresults.com/results/gprus04/CAT002RS.HTM
# 2005, CN: http://www.isuresults.com/results/gpchn04/CAT002RS.HTM
# 2005, JP: http://www.isuresults.com/results/gpjpn04/CAT002RS.HTM
# 2005, FN: http://www.isuresults.com/results/gpf0405/CAT002RS.HTM
# 2005, EU: http://www.isuresults.com/results/ec2005/CAT002RS.HTM
# 2017, FN: http://www.isuresults.com/results/season1617/gpf1617/CAT002RS.HTM
# 2017, EU: http://www.isuresults.com/results/season1617/ec2017/CAT002RS.HTM
# 2017, 4C: http://www.isuresults.com/results/season1617/fc2017/CAT002RS.HTM
# 2017, WR: http://www.isuresults.com/results/season1617/wc2017/CAT002RS.HTM
# 2018, US: http://www.isuresults.com/results/season1718/gpusa2017/CAT002RS.HTM
# 2018, CA: http://www.isuresults.com/results/season1718/gpcan2017/CAT002RS.HTM
# 2018, FR: http://www.isuresults.com/results/season1718/gpfra2017/CAT002RS.HTM
# 2018, RU: http://www.isuresults.com/results/season1718/gprus2017/CAT002RS.HTM
# 2018, CN: http://www.isuresults.com/results/season1718/gpchn2017/CAT002RS.HTM
# 2018, JP: http://www.isuresults.com/results/season1718/gpjpn2017/data0290.htm
# 2018, FN: http://www.isuresults.com/results/season1718/gpf1718/data0290.htm
# 2018, EU: http://www.isuresults.com/results/season1718/ec2018/CAT002RS.HTM
# 2018, 4C: http://www.isuresults.com/results/season1718/fc2018/CAT002RS.HTM
# 2018, OL: http://www.isuresults.com/results/season1718/owg2018/CAT002RS.HTM
# 2018, WR: http://www.isuresults.com/results/season1718/wc2018/CAT002RS.HTM
# 2019, US: http://www.isuresults.com/results/season1819/gpusa2018/CAT002RS.HTM
# 2019, CA: http://www.isuresults.com/results/season1819/gpcan2018/CAT002RS.HTM
# 2019, FR: http://www.isuresults.com/results/season1819/gpfra2018/CAT002RS.HTM
# 2019, RU: http://www.isuresults.com/results/season1819/gprus2018/CAT002RS.HTM
# 2019, JP: http://www.isuresults.com/results/season1819/gpjpn2018/data0290.htm
# 2019, FI: http://www.isuresults.com/results/season1819/gpfin2018/CAT002RS.HTM
# 2019, FN: http://www.isuresults.com/results/season1819/gpf1819/CAT002RS.HTM
# 2019, EU: http://www.isuresults.com/results/season1819/ec2019/CAT002RS.HTM
# 2019, 4C: http://www.isuresults.com/results/season1819/fc2019/CAT002RS.HTM

# %%
female_scores_df = pd.concat(female_scores,axis=0).reset_index(drop=True)
female_count_check = female_scores_df.groupby(['year', 'event']).size()
female_count_check = female_count_check.unstack().fillna(0).astype(int)
female_count_check = female_count_check.loc[female_counts.index, female_counts.columns]
np.all(female_count_check == female_counts)
# Out:
# True

# %% [markdown]
# ## Clean up scores

# %% [markdown]
# Remove French event in 2015-2016 season due to Paris attack (only short program performed)

# %%
male_scores_df = male_scores_df.loc[~((male_scores_df['year'] == 2016) & (male_scores_df['event'] == 'FR'))]
female_scores_df = female_scores_df.loc[~((female_scores_df['year'] == 2016) & (female_scores_df['event'] == 'FR'))]

# %% [markdown]
# ### Standardize skater name by extracting first and last names from raw names (messy order)

# %%
def standardize_names(names, last_name_pattern):
    last_names = names.str.findall(last_name_pattern).apply(' '.join).str.strip().str.replace('\xa0', ' ')
    first_names = names.str.replace(last_name_pattern, '').str.strip().str.replace('\xa0', ' ')
    return last_names, first_names, first_names + ', ' + last_names

# %%
def add_standardized_names(score_df, verbose=False):
    score_df = score_df.copy()
    last_name_patterns = [r'([A-ZÄÖÜ-]+[A-ZÄÖÜ])', r'([A-Za-zÄÖÜ]+[A-ZÄÖÜ])']
    mismatch_filter = np.full(len(score_df), 1).astype(bool)
    
    for pattern in last_name_patterns:
        last_names, first_names, full_names = standardize_names(score_df.loc[mismatch_filter, 'name'], pattern)
        score_df.loc[mismatch_filter, 'last_name'] = last_names
        score_df.loc[mismatch_filter, 'first_name'] = first_names
        score_df.loc[mismatch_filter, 'full_name'] = full_names
        mismatch_filter = (score_df['name'].str.len()+1 != score_df['full_name'].str.len())
    
    if verbose:
        print(f'Final {mismatch_filter.sum()} mismatches')
        if mismatch_filter.sum():
            print(score_df.loc[mismatch_filter])
    return score_df

# %%
male_scores_std = add_standardized_names(male_scores_df, verbose=True)
# Out:
# Final 1 mismatches
#                      name   score event  year last_name      first_name  \
# 877  van der PERREN Kevin  189.84    OL  2010    PERREN  van der  Kevin
#
#                   full_name
# 877  van der  Kevin, PERREN

# %%
male_scores_std.loc[877, ['last_name', 'first_name', 'full_name']] = ['VAN DER PERREN', 'Kevin', 'Kevin, VAN DER PERREN']
male_scores_std.loc[877]
# Out:
# name           van der PERREN Kevin
# score                        189.84
# event                            OL
# year                           2010
# last_name            VAN DER PERREN
# first_name                    Kevin
# full_name     Kevin, VAN DER PERREN
# Name: 877, dtype: object

# %%
female_scores_std = add_standardized_names(female_scores_df, verbose=True)
# Out:
# Final 0 mismatches

# %% [markdown]
# ### Standardize alternative spellings of first names (manually)

# %%
def filter_multiple_names(score_df, mother_col, child_col):
    def filter_func(group):
        return group[child_col].nunique() > 1
    filtered_rows = score_df.groupby(mother_col).filter(filter_func)
    return filtered_rows.drop_duplicates(subset=[mother_col, child_col]).sort_values(by=[mother_col, child_col])

# %%
def replace_names(score_df, name_col, replacement_dict):
    score_df = score_df.copy()
    for old_name, new_name in replacement_dict.items():
        score_df[name_col] = score_df[name_col].str.replace(old_name, new_name)
        score_df['full_name'] = score_df['full_name'].str.replace(old_name, new_name)
    return score_df

# %% [markdown]
# Female

# %%
female_first_replacements = {
    'Michelle': 'Michele',
    'Da Bin': 'Dabin',
    'Anastasiya': 'Anastasia',
    'Hae Jin': 'Haejin',
    'Na Hyun': 'Nahyun',
    'Yu-Na': 'Yuna',
    'Min-Jeong': 'Min-Jung',
    'So Youn': 'Soyoun',
    'Melinda Sherilyn': 'Melinda'}

# %%
female_scores_std = replace_names(female_scores_std, 'first_name', female_first_replacements)
filter_multiple_col(female_scores_std, 'last_name', 'first_name')
# Out:
#                        name   score event  year  last_name   first_name  \
# 243               Mai ASADA  141.65    4C  2006      ASADA          Mai
# 166               Mao ASADA  182.42    FR  2006      ASADA          Mao
# 119       Ana Cecilia CANTU   81.88    4C  2005      CANTU  Ana Cecilia
# 113          Michelle CANTU   93.99    4C  2005      CANTU      Michele
# 116              Diane CHEN   86.02    4C  2005       CHEN        Diane
# 2181            Hongyi CHEN  150.50    4C  2019       CHEN       Hongyi
# 1617             Karen CHEN  172.54    US  2016       CHEN        Karen
# 1721            Da Bin CHOI  173.71    4C  2016       CHOI        Dabin
# 107             Ji Eun CHOI  122.68    4C  2005       CHOI       Ji Eun
# 17            Mira, LEUNG
# 2179    Yi Christy, LEUNG
# 1815        Xiangning, LI
# 1231            Zijun, LI
# 716         Chaochih, LIU
# 41               Yan, LIU
# 1412         Soyoun, PARK
# 1290       Yeon Jun, PARK
# 1515         Angela, WANG
# 569         Melinda, WANG
# 573            Tina, WANG
# 513          Yueren, WANG
# 457       Caroline, ZHANG
# 10             Fan, ZHANG
# 1093         Kexin, ZHANG
# 1234          Ying, ZHANG

# %% [markdown]
# Male

# %%
male_first_replacements = {
    'Jun Hwan': 'Junhwan',
    'Leslie Man Cheuk': 'Leslie',
    'Jin Seo': 'Jinseo',
    'Morisi': 'Moris'}

# %%
male_scores_std = replace_names(male_scores_std, 'first_name', male_first_replacements)
filter_multiple_col(male_scores_std, 'last_name', 'first_name')
# Out:
#                             name   score event  year    last_name  \
# 1702            Jiri BELOHRADSKY  168.57    EU  2016  BELOHRADSKY
# 2161          Matyas BELOHRADSKY  191.22    EU  2019  BELOHRADSKY
# 1779                 Nathan CHEN  264.80    FR  2017         CHEN
# 964                 Peitong CHEN  150.69    CN  2011         CHEN
# 545             Javier FERNANDEZ  154.10    EU  2008    FERNANDEZ
# 422           Nicholas FERNANDEZ  103.43    4C  2007    FERNANDEZ
# 799                  Jinlin GUAN  187.95    CN  2010         GUAN
# 1518                 Yuhang GUAN  177.66    CN  2015         GUAN
# 1132            Dmitri IGNATENKO  154.88    EU  2012    IGNATENKO
# 1254             Pavel IGNATENKO  171.18    EU  2013    IGNATENKO
# 1282                 Jin Seo KIM  171.01    4C  2013          KIM
# 714                 KIM Min-Seok  108.75    4C  2009          KIM
# 1411                Dong Won LEE  166.73    4C  2014          LEE
# 112                Dong-Whun LEE  106.64    4C  2005          LEE
# 1583           Harry Hau Yin LEE  134.10    4C  2015          LEE
# 1280             June Hyoung LEE  176.39    4C  2013          LEE
# 1865                Sihyeong LEE  195.72    4C  2017          LEE
# 91                LIEBERS Martin  141.43    EU  2005      LIEBERS
# 541                Peter LIEBERS  165.14    EU  2008      LIEBERS
# 2079                    Jimmy MA  185.06    US  2019           MA
# 19                   Xiaodong MA  153.57    CA  2005           MA
# 608                 Ian MARTINEZ  155.18    US  2009     MARTINEZ
# 1279  Michael Christian MARTINEZ  178.08    4C  2013     MARTINEZ
# 5                       Lun SONG  161.46    US  2005         SONG
# 846                     Nan SONG  209.68    4C  2010         SONG
# 704                    TEN Denis  184.82    4C  2009          TEN
# 618                   Jeremy TEN  169.79    CA  2009          TEN
# 363           Alexander USPENSKI  178.59    CN  2007     USPENSKI
# 619            Vladimir USPENSKI  150.50    CA  2009     USPENSKI
# 775                    Chao YANG  178.63    FR  2010         YANG
# 417                  Zhixue YANG  154.57    4C  2007         YANG
# 1954                    He ZHANG  167.58    CN  2018        ZHANG
# 36                     Min ZHANG  186.04    RU  2005        ZHANG
#
#              first_name                    full_name
# 1702               Jiri            Jiri, BELOHRADSKY
# 2161             Matyas          Matyas, BELOHRADSKY
# 1779             Nathan                 Nathan, CHEN
# 964             Peitong                Peitong, CHEN
# 545              Javier            Javier, FERNANDEZ
# 422            Nicholas          Nicholas, FERNANDEZ
# 799              Jinlin                 Jinlin, GUAN
# 1518             Yuhang                 Yuhang, GUAN
# 1132             Dmitri            Dmitri, IGNATENKO
# 1254              Pavel             Pavel, IGNATENKO
# 1282             Jinseo                  Jinseo, KIM
# 714            Min-Seok                Min-Seok, KIM
# 1411           Dong Won                Dong Won, LEE
# 112           Dong-Whun               Dong-Whun, LEE
# 1583      Harry Hau Yin           Harry Hau Yin, LEE
# 1280        June Hyoung             June Hyoung, LEE
# 1865           Sihyeong                Sihyeong, LEE
# 91               Martin              Martin, LIEBERS
# 541               Peter               Peter, LIEBERS
# 2079              Jimmy                    Jimmy, MA
# 19             Xiaodong                 Xiaodong, MA
# 608                 Ian                Ian, MARTINEZ
# 1279  Michael Christian  Michael Christian, MARTINEZ
# 5                   Lun                    Lun, SONG
# 846                 Nan                    Nan, SONG
# 704               Denis                   Denis, TEN
# 618              Jeremy                  Jeremy, TEN
# 363           Alexander          Alexander, USPENSKI
# 619            Vladimir           Vladimir, USPENSKI
# 775                Chao                   Chao, YANG
# 417              Zhixue                 Zhixue, YANG
# 1954                 He                    He, ZHANG
# 36                  Min                   Min, ZHANG

# %% [markdown]
# ### Standardize alternative spellings of last names (manually)

# %% [markdown]
# Male

# %%
male_last_replacements = {'McNAMARA': 'MCNAMARA'}
male_scores_std = replace_names(male_scores_std, 'last_name', male_last_replacements)
list(filter_multiple_names(male_scores_std, 'first_name', 'last_name')['last_name'])
# Out:
# ['RIPPON',
#  'SIAO HIM FA',
#  'ALVARADO',
#  'SCHULTHEISS',
#  'JOHNSON',
#  'MAJOROV',
#  'PETROV',
#  'SAMARIN',
#  'SHUBIN',
#  'USPENSKI',
#  'BYCHENKO',
#  'KRASNOZHON',
#  'GRIAZEV',
#  'LAZUKIN',
#  'LEZIN',
#  'LUTAI',
#  'ROGOZINE',
#  'DMITRIEV',
#  'GACHINSKI',
#  'CALUZA',
#  'MABEE',
#  'MURAKAMI',
#  'TAKAHASHI',
#  'GRASSL',
#  'SAMOHIN',
#  'MARGALIK',
#  'TEN',
#  'WIECZOREK',
#  'ALIEV',
#  'IGNATENKO',
#  'MACYPURA',
#  'REZNICHENKO',
#  'DINEV',
#  'PAVLOV',
#  'RIGHINI',
#  'SHMURATKO',
#  'TRETIAKOV',
#  'FERNANDEZ',
#  'RAYA',
#  'ABBOTT',
#  'TEN',
#  'ALVES',
#  'AYMOZ',
#  'REYNOLDS',
#  'VAN DER PERREN',
#  'MENSHOV',
#  'TUPIKOV',
#  'PRECIOUS',
#  'SAVOIE',
#  'KOVTUN',
#  'SHIPOV',
#  'NOVALES',
#  'WEISS',
#  'KVITELASHVILI',
#  'PFEIFHOFER',
#  'FERNANDEZ',
#  'VRDOLJAK',
#  'YOUNG',
#  'CHAN',
#  'MYZYK',
#  'IGNATENKO',
#  'KASKA',
#  'SADOVSKY',
#  'SEROV',
#  'BRADLEY',
#  'JAHNKE',
#  'DAVYDOV',
#  'DOBRIN',
#  'KOTOV',
#  'VORONOV',
#  'LAMBIEL',
#  'WALKER',
#  'DOLENSKY',
#  'GOEBEL',
#  'PFEIFER',
#  'ROMANENKOV',
#  'DANILCHENKO',
#  'SAZONETS',
#  'LITVINTSEV',
#  'USPENSKI',
#  'KELEMEN',
#  'TOTH']

# %% [markdown]
# Female

# %%
female_last_replacements = {
    'McCORKELL': 'MCCORKELL',
    'LEPISTÖ': 'LEPISTO',
    'PÖYKIÖ': 'POYKIO',
    'TUKTAMYSHEVA': 'TUKTAMISHEVA'}
female_scores_std = replace_names(female_scores_std, 'last_name', female_last_replacements)
list(filter_multiple_names(female_scores_std, 'first_name', 'last_name')['last_name'])
# Out:
# ['KITAMURA',
#  'SUZUKI',
#  'FEIGIN',
#  'IEVLEVA',
#  'KUNOVA',
#  'NAJARRO',
#  'FJODOROVA',
#  'ZAGITOVA',
#  'DREI',
#  'MIKONSAARI',
#  'DOBBS',
#  'NYLANDER',
#  'CORWIN',
#  'GLENN',
#  'GALUSTYAN',
#  'GIMAZETDINOVA',
#  'KREUZER',
#  'MONTESINOS CANTU',
#  'NIKODINOV',
#  'WANG',
#  'MADSEN',
#  'ÖSTLUND',
#  'JURKIEWICZ',
#  'KHNYCHENKOVA',
#  'OVCHAROVA',
#  'POGORILAYA',
#  'CAIN',
#  'WAGNER',
#  'PANENKOVA',
#  'TIMOSHENKO',
#  'CHEN',
#  'SZMIETT',
#  'PROYDA',
#  'RYABOVA',
#  'GLEBOVA',
#  'LIASHENKO',
#  'RADIONOVA',
#  'SOKOLOVA',
#  'TUKTAMISHEVA',
#  'UKOLOVA',
#  'HUGHES',
#  'NAPHTAL',
#  'EFREMENKO',
#  'MANIACHENKO',
#  'MOVCHAN',
#  'SLUTSKAYA',
#  'OLSSON',
#  'PIEMAN',
#  'LIPNITSKAIA',
#  'SAUTER',
#  'SEBESTYEN',
#  'CHEN',
#  'VENHUIZEN',
#  'DORONINA',
#  'MAKAROVA',
#  'DOWNING',
#  'LEPISTO',
#  'ASADA',
#  'MIHARA',
#  'ARTEMIEVA',
#  'DIKANOVIC',
#  'SOTSKOVA',
#  'STAVITSKAIA',
#  'ALLELY',
#  'WESSENBERG',
#  'CANTU',
#  'KWAN',
#  'LONG',
#  'RAJICOVA',
#  'SCHOTT',
#  'EDMUNDS',
#  'KOROBEYNIKOVA',
#  'SHELEPEN',
#  'TSURSKAYA',
#  'HONGO',
#  'KIHIRA',
#  'HECKEN',
#  'MEIER',
#  'FONTANA',
#  'HUGEC',
#  'BIRYUKOVA',
#  'SAMODUROVA',
#  'LAFUENTE',
#  'RADEVA',
#  'STUERZINGER',
#  'WANG',
#  'HELGESSON',
#  'PAVUK',
#  'VOLCHKOVA',
#  'SHIN',
#  'YUN',
#  'KIM',
#  'SHIRAIWA']

# %% [markdown]
# ### Final check for any unusual duplications (do not share first and last name but full name almost identical)

# %% [markdown]
# Check by seeing if full names of skaters with the same first and last initial are almost identical

# %% [markdown]
# None found among males

# %%
unique_male_names = male_scores_std.drop_duplicates('full_name').copy()
unique_male_names['first_last_initial'] = unique_male_names['last_name'].str.get(0) + unique_male_names['first_name'].str.get(0)
list(unique_male_names.loc[unique_male_names.duplicated('first_last_initial', keep=False)].sort_values(by='first_last_initial')['full_name'])
# Out:
# ['Kevin, ALVES',
#  'Kevin, AYMOZ',
#  'Manol, ATANASSOV',
#  'Max, AARON',
#  'Artem, BORODULIN',
#  'Alexei, BYCHENKO',
#  'Clemens, BRUMMER',
#  'Chafik, BESSEGHIER',
#  'Jiri, BELOHRADSKY',
#  'Jason, BROWN',
#  'Jeffrey, BUTTLE',
#  'Michal, BREZINA',
#  'Matyas, BELOHRADSKY',
#  'Ryan, BRADLEY',
#  'Ruben, BLOMMAERT',
#  'Se Jong, BYUN',
#  'Stuart, BECKINGHAM',
#  'Jeremie, COLOT',
#  'Junhwan, CHA',
#  'Maciej, CIEPLUCHA',
#  'Marc Andre, CRAIG',
#  'Peitong, CHEN',
#  'Patrick, CHAN',
#  'Petr, COUFAL',
#  'Sean, CARLOW',
#  'Stephen, CARRIERE',
#  'Samuel, CONTESTI',
#  'Andrew, DODDS',
#  'Artur, DMITRIEV',
#  'Sergei, DAVYDOV',
#  'Sergei, DOBRIN',
#  'Joshua, FARRIS',
#  'Javier, FERNANDEZ',
#  'Andrei, GRIAZEV',
#  'Artur, GACHINSKI',
#  'Josip, GLUHAK',
#  'Jinlin, GUAN',
#  'Yakov, GODOROZHA',
#  'Yuhang, GUAN',
#  'Jorik, HENDRICKX',
#  'John, HAMER',
#  'Takeshi, HONDA',
#  'Tomoki, HIWATASHI',
#  'Brian, JOUBERT',
#  'Boyang, JIN',
#  'Anton, KOVALEVSKI',
#  'Alexei, KRASNOZHON',
#  'Alex Kang Chan, KAM',
#  'Alexandr, KAZAKOV',
#  'Maxim, KOVTUN',
#  'Moris, KVITELASHVILI',
#  'Manuel, KOLL',
#  'Mikhail, KOLYADA',
#  'Min-Seok, KIM',
#  'Sergei, KOTOV',
#  'Stephen Li-Chung, KUO',
#  'Sei, KAWAHARA',
#  'Andrei, LEZIN',
#  'Andrei, LUTAI',
#  'Andrei, LAZUKIN',
#  'Davide, LEWTON BRAIN',
#  'Dong-Whun, LEE',
#  'Dong Won, LEE',
#  'Martin, LIEBERS',
#  'Micah Kai, LYNETTE',
#  'Stefan, LINDEMANN',
#  'Sihyeong, LEE',
#  'Stephane, LAMBIEL',
#  'Armin, MAHBANOOZADEH',
#  'Alexander, MAJOROV',
#  'Boris, MARTINEC',
#  'Brandon, MROZ',
#  'Denis, MARGALIK',
#  'Daisuke, MURAKAMI',
#  'Igor, MACYPURA',
#  'Ian, MARTINEZ',
#  'Irakli, MAYSURADZE',
#  'Keegan, MESSING',
#  'Konstantin, MENSHOV',
#  'Luiz, MANELLA',
#  'Luc, MAIERHOFER',
#  'Miguel Angel, MOYRON',
#  'Michael Christian, MARTINEZ',
#  'Ross, MINER',
#  'Robert, MCNAMARA',
#  'Tatsuki, MACHIDA',
#  'Takahito, MURA',
#  'Kento, NAKAMURA',
#  'Kensuke, NAKANIWA',
#  'Nam, NGUYEN',
#  'Nicolas, NADEAU',
#  'Adian, PITKEEV',
#  'Alexander, PETROV',
#  'Alban, PREAUBERT',
#  'Moris, PFEIFHOFER',
#  'Matthew, PRECIOUS',
#  'Yaroslav, PANIOT',
#  'Yannick, PONSERO',
#  'Abzal, RAKIMGALIEV',
#  'Andrei, ROGOZINE',
#  'Adam, RIPPON',
#  'Aidas, REKLYS',
#  'Igor, REZNICHENKO',
#  'Ivan, RIGHINI',
#  'Javier, RAYA',
#  'Joey, RUSSELL',
#  'Aleksandr, SELEVKO',
#  'Adrian, SCHULTHEISS',
#  'Adam, SIAO HIM FA',
#  'Alexander, SHUBIN',
#  'Alexander, SAMARIN',
#  'Juraj, SVIATKO',
#  'Justus, STRID',
#  'Maxim, SHIPOV',
#  'Matthew, SAVOIE',
#  'Ryo, SHIBATA',
#  'Roman, SEROV',
#  'Roman, SADOVSKY',
#  'Shawn, SAWYER',
#  'Scott, SMITH',
#  'Silvio, SMALUN',
#  'Dean, TIMMINS',
#  'Daisuke, TAKAHASHI',
#  'Denis, TEN',
#  'Konstantin, TUPIKOV',
#  'Kazuki, TOMONO',
#  'Keiji, TANAKA',
#  'Joel, WATSON',
#  'Jialiang, WU',
#  'Johnny, WEIR',
#  'Mark, WEBSTER',
#  'Michael, WEISS',
#  'Mathieu, WILSON',
#  'Maurizio, ZANDRON',
#  'Min, ZHANG']

# %% [markdown]
# None found among females

# %%
unique_female_names = female_scores_std.drop_duplicates('full_name').copy()
unique_female_names['first_last_initial'] = unique_female_names['last_name'].str.get(0) + unique_female_names['first_name'].str.get(0)
list(unique_female_names.loc[unique_female_names.duplicated('first_last_initial', keep=False)].sort_values(by='first_last_initial')['full_name'])
# Out:
# ['Miki, ANDO',
#  'Maria, ARTEMIEVA',
#  'Mao, ASADA',
#  'Megan, ALLELY',
#  'Matilda, ALGOTSSON',
#  'Mai, ASADA',
#  'Starr, ANDREWS',
#  'Shizuka, ARAKAWA',
#  'Corenne, BRUHNS',
#  'Christiane, BERGER',
#  'Eveline, BRUNNER',
#  'Eliska, BREZINOVA',
#  'Jenna-Anne, BUYS',
#  'Jacqueline, BELENYESIOVA',
#  'Melissa, BULANHAGUI',
#  'Mariah, BELL',
#  'Romy, BÜHLER',
#  'Radka, BARTOVA',
#  'Sofia, BIRYUKOVA',
#  'Stefania, BERTON',
#  'Amber, CORWIN',
#  'Anne Sophie, CALVEZ',
#  'Alissa, CZISNY',
#  'Ashley, CAIN',
#  'Alaine, CHARTRAND',
#  'Ana Cecilia, CANTU',
#  'Diane, CHEN',
#  'Dabin, CHOI',
#  'Ji Eun, CHOI',
#  'Joanne, CARTER',
#  'Kailani, CRAINE',
#  'Karen, CHEN',
#  'Micol, CRISTINI',
#  'Mimi Tanasorn, CHINDASOOK',
#  'Michele, CANTU',
#  'Sasha, COHEN',
#  'Samantha, CESARIO',
#  'Song Joo, CHEA',
#  'Antonina, DUBININA',
#  'Amanda, DOBBS',
#  'Alisa, DREI',
#  'Annette, DYTRT',
#  'Adriana, DESANCTIS',
#  'Gwendoline, DIDIER',
#  'Gabrielle, DALEMAN',
#  'Laura, DOWNING',
#  'Lea Johanna, DASTICH',
#  'Michaela, DU TOIT',
#  'Maria, DIKANOVIC',
#  'Meagan, DUHAMEL',
#  'Alina, FJODOROVA',
#  'Alexandra, FEIGIN',
#  'Anastasia, GALUSTYAN',
#  'Aleksandra, GOLOVKINA',
#  'Alexe, GILLES',
#  'Alice, GARLISI',
#  'Anne Line, GJERSEM',
#  'Anastasia, GIMAZETDINOVA',
#  'Amber, GLENN',
#  'Camilla, GJERSEM',
#  'Christina, GAO',
#  'Elene, GEDEVANISHVILI',
#  'Elena, GLEBOVA',
#  'Lenaelle, GILLERON-GORRY',
#  'Lucrezia, GENNARO',
#  'Manouk, GIJSMAN',
#  'Marta, GARCIA',
#  'Jocelyn, HO',
#  'Joshi, HELGESSON',
#  'Katherine, HADFORD',
#  'Katrina, HACKER',
#  'Loretta, HAMUI',
#  'Loena, HENDRICKX',
#  'Lesley, HAWKER',
#  'Michaela-Lucie, HANZLIKOVA',
#  'Marin, HONDA',
#  'Rika, HONGO',
#  'Reyna, HAMUI',
#  'Sarah, HECKEN',
#  'Silvia, HUGEC',
#  'Shirene, HUMAN',
#  'Shoko, ISHIKAWA',
#  'Svetlana, ISSAKOVA',
#  'Angelina, KUCHVALSKA',
#  'Alexandra, KUNOVA',
#  'Agata, KRYGER',
#  'Andrea, KREUZER',
#  'Akiko, KITAMURA',
#  'Anna, KHNYCHENKOVA',
#  'Chae-Hwa, KIM',
#  'Chantelle, KERRY',
#  'Crystal, KIANG',
#  'Carolina, KOSTNER',
#  'Elina, KETTUNEN',
#  'Elzbieta, KROPA',
#  'Haejin, KIM',
#  'Hyeon-Jung, KIM',
#  'Hanul, KIM',
#  'Michele, KWAN',
#  'Mariko, KIHARA',
#  'Min-Jung, KWAK',
#  'Na-Young, KIM',
#  'Nahyun, KIM',
#  'Riona, KATO',
#  'Rika, KIHIRA',
#  'Sandra, KHOPON',
#  'Stanislava, KONSTANTINOVA',
#  'Tamar, KATZ',
#  'Tugba, KARADEMIR',
#  'Tae Kyung, KIM',
#  'Yelim, KIM',
#  'Yuna, KIM',
#  'Amy, LIN',
#  'Amelie, LACOSTE',
#  'Alena, LEONOVA',
#  'Cheltzie, LEE',
#  'Chaochih, LIU',
#  'Eunsoo, LIM',
#  'Elisabetta, LECCARDI',
#  'Elena, LIASHENKO',
#  'Laurine, LECAVELIER',
#  'Laura, LEPISTO',
#  'Myriam, LEUENBERGER',
#  'Michele, LONG',
#  'Mira, LEUNG',
#  'Yulia, LIPNITSKAYA',
#  'Yan, LIU',
#  'Yi Christy, LEUNG',
#  'Aiza, MAMBEKOVA',
#  'Andrea, MONTESINOS CANTU',
#  'Anita, MADSEN',
#  'Alisa, MIKONSAARI',
#  'Arina, MARTINOVA',
#  'Ksenia, MAKAROVA',
#  'Kanako, MURAKAMI',
#  'Kristine, MUSADEMBA',
#  'Kimmie, MEISSNER',
#  'Lejeanne, MARAIS',
#  'Lena, MARROCCO',
#  'Miriam, MANZANO',
#  'Mae Berenice, MEITE',
#  'Maisy Hiu Ching, MA',
#  'Mai, MIHARA',
#  'Satoko, MIYAHARA',
#  'Sarah, MEIER',
#  'Victoria, MUNIZ',
#  'Valeriia, MIKHAILOVA',
#  'Valentina, MARCHEI',
#  'Veronik, MALLET',
#  'Alexandra, NAJARRO',
#  'Amanda, NYLANDER',
#  'Angela, NIKODINOV',
#  'Miyu, NAKASHIO',
#  'Mirai, NAGASU',
#  'Yuka, NAGAI',
#  'Yukari, NAKANO',
#  'Yoshie, ONDA',
#  'Yukina, OTA',
#  'Alexia, PAGANINI',
#  'Alicia, PINEAULT',
#  'Ami, PAREKH',
#  'Abigail, PIETERSEN',
#  'Anna, POGORILAYA',
#  'Alisson Krystle, PERTICHETO',
#  'Constanze, PAULINUS',
#  'Cynthia, PHANEUF',
#  'Daria, PANENKOVA',
#  'Diana, POTH',
#  'Ekaterina, PROYDA',
#  'Emmi, PELTONEN',
#  'Natalia, POPOVA',
#  'Nina, PETUSHKOVA',
#  'Susanna, POYKIO',
#  'Soyoun, PARK',
#  'Sarah-Yvonne, PRYTULA',
#  'Ekaterina, RYABOVA',
#  'Elena, RADIONOVA',
#  'Adelina, SOTNIKOVA',
#  'Akiko, SUZUKI',
#  'Aki, SAWADA',
#  'Julia, SEBESTYEN',
#  'Julia, SAUTER',
#  'Julianne, SEGUIN',
#  'Joanna, SO',
#  'Monika, SIMANCIKOVA',
#  'Myriane, SAMSON',
#  'Maria, SOTSKOVA',
#  'Maria, STAVITSKAIA',
#  'Melanie, SWANG',
#  'Nella, SIMAOVA',
#  'Nicole, SCHOTT',
#  'Natalie, SANGKAGALO',
#  'Polina, SHELEPEN',
#  'Pernille, SORENSEN',
#  'Sofia, SAMODUROVA',
#  'Sila, SAYGI',
#  'Serafima, SAKHANOVICH',
#  'Suh Hyun, SON',
#  'Tina, STUERZINGER',
#  'Tammy, SUTAN',
#  'Yea-Ji, SHIN',
#  'Yretha, SILETE',
#  'Yuna, SHIRAIWA',
#  'Elizaveta, TUKTAMISHEVA',
#  'Elizabet, TURSYNBAEVA',
#  'Karen, VENHUIZEN',
#  'Kaat, VAN DAELE',
#  'Angela, WANG',
#  'Ashley, WAGNER',
#  'Megan, WESSENBERG',
#  'Melinda, WANG',
#  'Nathalie, WEINZIERL',
#  'Niki, WORIES',
#  'Yasmine Kimiko, YAMADA',
#  'Yea-Ji, YUN',
#  'Agnes, ZAWADZKI',
#  'Alina, ZAGITOVA',
#  'Christine, ZUKOWSKI',
#  'Caroline, ZHANG']

# %% [markdown]
# ### Trim and rearrange columns for final save

# %%
def trim_df(df):
    df = df.drop('name', axis=1)
    df = df.rename({'full_name': 'name'}, axis=1)
    return df[['name', 'year', 'event', 'score']]

# %%
male_scores_trimmed = trim_df(male_scores_std)
female_scores_trimmed = trim_df(female_scores_std)

# %% [markdown]
# ## Save relevant scores

# %%
male_scores_df.to_csv('scores/raw_male.csv', index=False)
female_scores_df.to_csv('scores/raw_female.csv', index=False)

# %%
male_scores_std.to_csv('scores/std_male.csv', index=False)
female_scores_std.to_csv('scores/std_female.csv', index=False)

# %%
male_scores_trimmed.to_csv('scores/trimmed_male.csv', index=False)
female_scores_trimmed.to_csv('scores/trimmed_female.csv', index=False)
